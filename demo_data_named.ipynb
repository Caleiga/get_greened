# %%
import pandas as pd
from data_named import variable_values, data
import matplotlib.pyplot as plt

# %%
print(variable_values['gender'][2])
# Out:
# female

# %%
for key in variable_values['gender'].keys():
    print("value: {}, meaning: {}".format(key, variable_values['gender'][key]))
# Out:
# value: 1, meaning: male
# value: 2, meaning: female
# value: 3, meaning: non-binary/third gender
# value: 4, meaning: prefer not to say
# value: 5, meaning: other
